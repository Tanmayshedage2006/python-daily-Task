# %% [raw]
# 1. Understanding the Core Concepts Perfectly
# Tuples: The Immutable Store
# A tuple is an ordered collection of elements, similar to a list, but with one major difference: it is immutable (cannot be changed after creation).
# •	Syntax: Uses parentheses ().
# •	Key Property: If you try to change an element (e.g., t[0] = 300), Python will throw a TypeError.
# •	Methods: Common methods include .count() to find occurrences and .index() to find the position of an element.
# Sets: The Unique Collection
# A set is an unordered collection of unique elements.
# •	Syntax: Uses curly braces {}.
# •	Key Property: It automatically removes duplicates. If you create a set with [1, 1, 2], it becomes {1, 2}.
# •	Operations: You can add elements with .add(), remove them with .remove(), and perform mathematical operations like Union (all items) and Intersection (common items).
# Dictionaries: The Key-Value Pair
# A dictionary stores data in key: value pairs, allowing you to look up information efficiently.
# •	Syntax: Uses curly braces with colons {key: value}.
# •	Key Property: Keys must be unique, and they are used to access the corresponding values (e.g., d['age'] returns 20).
# •	Usage: Often used to represent structured data, like a person's profile or a database record.

# %% [raw]
# 2. Practice Questions
# Part A: Tuples (Immutability & Indexing)
# 1.	Immutability: Given t = (1, 2, 3), what happens if you run t[1] = 20?
# 2.	Counting: If y = (1, 1, 2, 3, 1), what is the output of y.count(1)?
# 3.	Indexing: How do you find the position of the value 7 in the tuple y = (10, 20, 7, 40)?
# 4.	Nested Tuples: Given u = (10, 20, (50, 60), 90), write the code to access the number 60.

# %%
t=(1,2,3)

# %%
t[1]=20 # it doesn't make changes after creating
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 t[1]=20
#
# TypeError: 'tuple' object does not support item assignment

# %%
y = (1, 1, 2, 3, 1)

# %%
y.count(1)
# Out:
# 3

# %%
y = (10, 20, 7, 40)

# %%
(y[2])
# Out:
# 7

# %%
u = (10, 20, (50, 60), 90)

# %%
(u[2][1])
# Out:
# 60

# %% [raw]
# Part B: Sets (Uniqueness & Logic)
# 5.	Duplicate Removal: What is the result of set([1, 2, 2, 3, 4, 4, 4])?
# 6.	Adding Items: How do you add the number 100 to a set named s?
# 7.	Removing Items: What method do you use to remove 20 from s = {10, 20, 30}?
# 8.	Union: If s1 = {1, 2} and s2 = {2, 3}, what is s1.union(s2)?
# 9.	Intersection: Using the same sets above, what is s1.intersection(s2)?

# %%
set([1, 2, 2, 3, 4, 4, 4]) # duplicates are not allowed
# Out:
# {1, 2, 3, 4}

# %%
set([1, 2, 2, 3, 4, 4, 4])
# Out:
# {1, 2, 3, 4}

# %%
set:(100)

# %%
set={10,20,30}

# %%
set.remove(10)

# %%
set
# Out:
# {20, 30}

# %%
s1={10,20}

# %%
s2={30,40}

# %%
s1.union(s2) # Taking all the elements
# Out:
# {10, 20, 30, 40}

# %%
s1.intersection(s2) # Nothing same elements in a set
# Out:
# set()

# %% [raw]
# Part C: Dictionaries (Key-Value Access)
# 10.	Value Retrieval: Given d = {'name': 'Sham', 'age': 20}, how do you get the age?
# 11.	Adding Data: How do you add a new key 'city' with value 'Mumbai' to dictionary d?
# 12.	Updating: How do you change the 'age' in d from 20 to 21?
# 13.	Keys & Values: What command returns all the keys present in a dictionary?
# 14.	Pop Method: What happens to dictionary d if you run d.pop('name')?

# %%
d = {'name': 'Sham', 'age': 20}
print(d['age'])
# Out:
# 20

# %%
d['city'] = 'Mumbai'

# %%
d
# Out:
# {'name': 'Sham', 'age': 20, 'city': 'Mumbai'}

# %%
d['age']=21

# %%
d
# Out:
# {'name': 'Sham', 'age': 21, 'city': 'Mumbai'}

# %%
d.pop('name')
# Out:
# 'Sham'

# %%
d
# Out:
# {'age': 21, 'city': 'Mumbai'}

# %% [raw]
# Part D: Mixed & Advanced Challenges
# 15.	Conversion: How do you convert a list [1, 2, 2] into a set to remove duplicates, and then back into a list?
# 16.	Nested Dictionary: Access 'Maths' score from results = {'student': 'Om', 'scores': {'Maths': 90, 'Science': 85}}.
# 17.	Tuple Length: How do you find how many elements are in t = (1, 2, 3, 4)?
# 18.	Set Membership: How do you check if 10 exists in set s? (Hint: Use the in keyword).
# 19.	Dictionary from List: Can you create a dictionary where keys are numbers 1, 2 and values are their squares 1, 4?
# 20.	Dictionary to DataFrame: Based on the notebook, what library is used to turn a dictionary into a table format (DataFrame)?

# %%
a=[1,2,2]
new__list = list(set(a))

# %%
print(new_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(new_list)
#
# NameError: name 'new_list' is not defined

# %%
result ={
    'student':'om'
     'scores': {
        'maths':90
         'science':85
     }
}
print(results['scores']['maths'])
# Out:
#   Cell In[15], line 3
#     'scores': {
#             ^
# SyntaxError: invalid syntax

# %%
t=(1,2,3,4,4,10)
len(t)
# Out:
# 6

# %%
10 in t
# Out:
# True

# %%
d{
    1:1
    2:4
}
# Out:
#   Cell In[20], line 2
#     1:1
#       ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
