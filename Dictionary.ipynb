# %%
student={
    "name":"Tanmay",
    "age":20,                 
    "course":"BCA"
}
print(student)
# Out:
# {'name': 'Tanmay', 'age': 20, 'course': 'BCA'}

# %%
student={"name":"Tanmay","age":20}    # Access a value
print(student["name"])
# Out:
# Tanmay

# %%
student={"name":"Tanmay","age":20}
student["city"]="satara"            # Add in new key-value pair

# %%
student
# Out:
# {'name': 'Tanmay', 'age': 20, 'city': 'satara'}

# %%
student["age"] =21  # update a value

# %%
student
# Out:
# {'name': 'Tanmay', 'age': 21, 'city': 'satara'}

# %%
del student["age"]   # del the key

# %%
student.keys()   # get all key
# Out:
# dict_keys(['name', 'city'])

# %%
print(student.values()) # Get all values
# Out:
# dict_values(['Tanmay', 21, 'satara'])

# %%
print("name" in student)  #
# Out:
# True

# %%
student={"name":"Tanmay","age":20}
new_student=student.copy()
print(new_student)
# Out:
# {'name': 'Tanmay', 'age': 20}

# %%
student={"name":"Tanmay","age":20}
for value in student.values():
    print(value)
# Out:
# Tanmay
# 20
