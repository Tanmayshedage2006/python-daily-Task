# %% [raw]
# 1]Even or odd checker
# write a function that takes a number as input and return whether it is even or odd.

# %%
def Even_odd(num):
    if num%2==0:
        print("Even")
    else:
        print("odd")

# %%
Even_odd(3)
# Out:
# odd

# %% [raw]
# 2] Maximum of Three numbers
# Create a function that accepts three numbers and return the largest.

# %%
def Max(a,b,c):
    if a>=b and a>=c:
        print=("a is greater than b")
    elif b>=a and b>=c:
         print=("b is greater than c")
    else:
        print=("c is greater than a and b")

# %%
max(2,5,6)
# Out:
# 6

# %% [raw]
# 3] Simple calculator
# write a function that accepts two numbers and an operator (+,-,*,/) and perform the operation.

# %%
def cal(a,b):
    print(a+b)
    print(a*b)
    print(a-b)
    print(a/b)

# %%
cal(3,5)
# Out:
# 8
# 15
# -2
# 0.6

# %% [raw]
# 4]palindrome checker:
# write a function to check if a given string is a palindrome (read the same as backward)

# %%
def palindrome(string):
    if string == string[::-1]:
        return True 
    else:
        return False
text=input("Enter a string:")

if palindrome(text):
    print("palindrome")
else:
    print("Not palindrome")
# Out:
# Enter a string: as
# Not palindrome

# %% [raw]
# 5] count vowels in a string

# %%
def count_vowel(string):
    count=0
    for ch in string :
        if ch.lowe() in "aeiou":
            count +=1
        return count

# %%
count_vowel(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 count_vowel(a)
#
# NameError: name 'a' is not defined

# %%
num=int(input("Enter a number"))
fact=1
while num>0:
    fact=fact*num
    num=num-1
