# %% [raw]
# Slicing in list
# Slicing Syntax [start : stop : step]:
#
# Start: The index where the slice begins (inclusive).
#
# Stop: The index where the slice ends (exclusive—it does not include the item at this index).
#
# Step: The jump between indices. A negative step (e.g., -1) reverses the direction.
#
# The "Empty" Rule: If the start or stop is left blank, Python assumes you want to go from the very beginning or until the very end of the list.

# %%
slice = [10, 20, 30, 40, 50, 60, 70, 80]

# %%
slice
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
slice[2:5]
# Out:
# [30, 40, 50]

# %%
slice[:4]
# Out:
# [10, 20, 30, 40]

# %%
slice[5:]
# Out:
# [60, 70, 80]

# %% [raw]
# How do you get every second element (e.g., [10, 30, 50, 70])

# %%
slice[::2]
# Out:
# [10, 30, 50, 70]

# %%
slice[::-1]
# Out:
# [80, 70, 60, 50, 40, 30, 20, 10]

# %%
slice[-4:-1]
# Out:
# [50, 60, 70]

# %%
slice[6:1:-2]
# Out:
# [70, 50, 30]

# %% [raw]
# How would you write a slice to get the last three elements

# %%
slice
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
slice[5:8]
# Out:
# [60, 70, 80]

# %%
nested = [1, 2, [100, 200, [300, 400]], 5]

# %%
nested[2]
# Out:
# [100, 200, [300, 400]]

# %%
nested[2][1]
# Out:
# 200

# %%
nested[2][2][1]
# Out:
# 400

# %% [raw]
# If you run nested[2][1] = 250, what does the list look like now?

# %%
nested = [1, 2, [100, 200, [300, 400]], 5]

# %%
nested[2][1]
# Out:
# 200

# %% [raw]
# How do you slice the inner list to get [100, 200]

# %%
nested[2][:2]
# Out:
# [100, 200]

# %% [raw]
# Part C: Advanced & Mixed Concepts
# Given: data = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
data = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %% [raw]
# How do you access the entire second row [4, 5, 6]

# %%
data[1]
# Out:
# [4, 5, 6]

# %% [raw]
# What is data[1][1:3]

# %%
data[1][1:3]
# Out:
# [5, 6]

# %% [raw]
# How do you access the number 9 using negative indexing

# %%
data[2][2]
# Out:
# 9

# %% [raw]
# If x = [1, 2, 3], what is the difference between x.append([4, 5]) and x.extend([4, 5])?

# %%
x=[1,2,3]

# %%
x.append([4,5]) # it add the values as it is

# %%
x
# Out:
# [1, 2, 3, [4, 5]]

# %%
x.extend([4,5]) # it add the indiviual / separtely

# %%
x
# Out:
# [1, 2, 3, [4, 5], 4, 5]

# %% [raw]
# Given: z = [10, 20, 50, 76, 89, 56, 87, 90]. What is z[-3::-1]

# %%
z = [10, 20, 50, 76, 89, 56, 87, 90]

# %%
z[-3::-1]
# Out:
# [56, 89, 76, 50, 20, 10]

# %% [raw]
# Write code to reverse only the middle three elements of a 5-element list

# %%
z=[10,20,30,40,50]

# %%
z[1:4]
# Out:
# [20, 30, 40]

# %% [raw]
# Create a nested list where the first element is a string, and the second element is a slice of [1, 2, 3, 4, 5].

# %%
nested=['2',nested[1:4]]

# %%
nested
# Out:
# ['2', [2, [100, 200, [300, 400]], 5]]
